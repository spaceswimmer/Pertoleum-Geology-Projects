# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split, cross_val_score
from xgboost import XGBRegressor

# %%
#Выгрузка данных - таблица с результатами ГИС (вставьте свою директорию)
filepath = '/Users/aleksandrbogdanov/MyJupyterNotebook/Logs.xlsx'
data = pd.read_excel(filepath)

# Ниже я просто решил поучиться преобразовывать таблицу в удобный вид. Можно было использовать эксель, но решил использовать функционал pandas


#Удаляем ненужный стобец
df = data.drop(data.columns[0], axis = 1)

#Преобразуем таблицу pandas в рабочий вид. Устанавливаем названия стобцов

col = np.array(df.iloc[0])
df.columns = col
df = df[1:]

df
# Out:
#       Depth       AK     BK       DS   GGKp      GK    GZ1    GZ2    GZ3  \
# 1      2790   280.79   7.78  220.058  2.512  10.453     12  11.52   8.78
# 2    2790.2  280.629   7.86   220.55   2.46  11.234  12.32  11.42    8.5
# 3    2790.4  281.805   7.78  220.182  2.405  11.061  12.02   11.2   8.02
# 4    2790.6  280.283   7.86  220.187   2.46   9.906     12  10.62   7.54
# 5    2790.8  279.355   7.63  219.342  2.493   9.465  10.83  10.72    7.4
# ..      ...      ...    ...      ...    ...     ...    ...    ...    ...
# 560    2907  261.106  11.32  206.309  2.474   6.809   9.73  10.48  12.72
# 561  2907.2   262.17  11.84  206.518  2.466    7.11  10.01  11.44     15
# 562  2907.4  258.656  12.67  206.443  2.449   7.116  11.01  12.24  16.93
# 563  2907.6   258.36  13.04  206.433  2.497   7.328  11.23  13.39  18.52
# 564  2907.8  262.529  15.44   206.09  2.537   6.547  12.04  13.51   20.1
#
#       GZ4   GZ5    GZ7  IK     MGZ   MPZ   MRES    NGK       PS     PZ  \
# 1    7.22  6.26   8.95  96   8.515  4.93  1.941  2.371  124.366  10.82
# 2    7.22  6.04    9.1  97   8.418  4.77  1.942  2.403  124.216  10.69
# 3    6.94   5.8      9  97   8.038  4.79  1.944  2.425  124.142  10.82
# 4    6.67  5.58   8.69  96   7.872  4.65  1.942  2.416  124.777  10.89
# 5    6.51  5.46   8.49  94   7.371  4.54  1.945  2.397   124.59  10.84
# ..    ...   ...    ...  ..     ...   ...    ...    ...      ...    ...
# 560  2.32  0.49  10.66  74  11.798  7.31  1.972   3.24  128.666  15.97
# 561   2.1  0.56  12.28  78  11.566  7.36  1.965  3.401  128.928  16.32
# 562   2.1  0.49  13.89  81  11.039  7.61  1.956  3.375  128.442  17.11
# 563  2.38  0.49  15.91  88  13.736  8.93  1.958  3.295  128.442  18.34
# 564   2.7  0.46  17.48  93  17.052  9.54  1.966  3.423  128.442  19.51
#
#             W
# 1    -99999.0
# 2    -99999.0
# 3    -99999.0
# 4    -99999.0
# 5    -99999.0
# ..        ...
# 560     0.244
# 561      0.22
# 562     0.224
# 563     0.236
# 564     0.217
#
# [564 rows x 20 columns]

# %%
#Удаляем стобец глубина и водородосодержание - непоказательные.

df = df.drop(['W'], axis=1)
#df = df.drop(['AK', 'BK', 'GZ1', 'GZ2', 'GZ3', 'GZ5', 'GZ4', 'GZ7', 'MGZ', 'MPZ', 'DS', 'MRES','PZ'], axis = 1)

# %% [markdown]
# Data analysis

# %%
# Посмотрим на наличие пропусков

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 1 to 564
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Depth   564 non-null    object
#  1   AK      564 non-null    object
#  2   BK      564 non-null    object
#  3   DS      564 non-null    object
#  4   GGKp    564 non-null    object
#  5   GK      564 non-null    object
#  6   GZ1     564 non-null    object
#  7   GZ2     564 non-null    object
#  8   GZ3     564 non-null    object
#  9   GZ4     564 non-null    object
#  10  GZ5     564 non-null    object
#  11  GZ7     564 non-null    object
#  12  IK      564 non-null    object
#  13  MGZ     564 non-null    object
#  14  MPZ     564 non-null    object
#  15  MRES    564 non-null    object
#  16  NGK     564 non-null    object
#  17  PS      564 non-null    object
#  18  PZ      564 non-null    object
# dtypes: object(19)
# memory usage: 83.8+ KB

# %%
# Переведем из типа object в float

df = df.astype('float64')

# %%
# Пропусков нет, посмотрим корреляцию признаков. Target - NGK

corr = df.corr()

plt.figure(figsize=(20, 10))

sns.heatmap(corr, cmap='coolwarm', annot=True, annot_kws={'fontsize':8})
# Out:
# <Axes: >

# %%
# Вследствие мультиколиннеарности удалим сильно коррелирующие признаки

df.drop(['GZ1', 'GZ2', 'GZ3', 'GZ5', 'GZ4', 'GZ7', 'MPZ', 'MGZ', 'MRES'], axis=1, inplace=True)

corr = df.corr()

plt.figure(figsize=(20, 10))

sns.heatmap(corr, cmap='coolwarm', annot=True, annot_kws={'fontsize':8})
# Out:
# <Axes: >

# %%
# Проверять на наличие выбросов не будем! В разрезе скважины есть толща с аномальными характеристиками
# несущая важную геологическую информацию - Баженовская нефтематеринская толща

# %% [markdown]
# Построение модели

# %%
X = df.drop(['NGK'], axis = 1)
y = df['NGK']

# Массив name для дальнейшего использования feature_importances
name_1 = df.drop(['NGK', 'Depth'], axis=1)
names = name_1.columns.to_list()

# %%
for col in X.columns:
    sns.scatterplot(x = X[col], y = y, color = 'r')
    plt.title(f'Зависимость {col} от NGK')
    plt.show()

# %%
# Видно, что зависимость нелинейная, попробуем использовать алгоритмы, построенные на деревьях для прогноза NGK

# %%
np.random.seed(42)

#Делим на тест и трейн первый раз - достанем тестовую глубину
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# Берем глубину для визуализации предсказаний каротажа
depth = X_test.loc[:, 'Depth']
X = X.drop('Depth', axis=1)

#Делим на тест и трейн
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
# Используем optuna и cross-валидацию для подбора гиперпараметров

def objective_GB(trial):
    
    max_depth = trial.suggest_int('max_depth', 2, 15, step = 3)
    n_estimators = trial.suggest_int('n_estimators', 10, 1000, 20)
    max_features = trial.suggest_categorical('max_features', [None, 'sqrt', 'log2'])
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log = True)
    
    score = cross_val_score(GradientBoostingRegressor(max_depth=max_depth, n_estimators=n_estimators,
                                                     max_features=max_features, learning_rate=learning_rate,
                                                     random_state=42),
                           X_train, y_train, cv=3, scoring='r2', n_jobs=-1).mean()
    return score

# %%
# Подбираем гиперпараметры

study_gb = optuna.create_study(direction='maximize')
study_gb.optimize(objective_GB, n_trials=30)
study_gb.best_params
# Out:
# [I 2024-04-10 21:37:02,305] A new study created in memory with name: no-name-82241a3f-739c-4467-9e85-c0c115543be0
# /Users/aleksandrbogdanov/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 15] and step=3, but the range is not divisible by `step`. It will be replaced by [2, 14].
#   warnings.warn(
# /var/folders/46/4js24d154nb0rgs9sp2kxk180000gn/T/ipykernel_23100/2490683891.py:6: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   n_estimators = trial.suggest_int('n_estimators', 10, 1000, 20)
# /Users/aleksandrbogdanov/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [10, 1000] and step=20, but the range is not divisible by `step`. It will be replaced by [10, 990].
#   warnings.warn(
# [I 2024-04-10 21:37:04,403] Trial 0 finished with value: 0.3713536470551035 and parameters: {'max_depth': 11, 'n_estimators': 890, 'max_features': 'log2', 'learning_rate': 0.00030596933460542275}. Best is trial 0 with value: 0.3713536470551035.
# [I 2024-04-10 21:37:04,978] Trial 1 finished with value: 0.01591267769153515 and parameters: {'max_depth': 8, 'n_estimators': 330, 'max_features': 'sqrt', 'learning_rate': 3.493681999321031e-05}. Best is trial 0 with value: 0.3713536470551035.
# [I 2024-04-10 21:37:06,096] Trial 2 finished with value: 0.13300808712070442 and parameters: {'max_depth': 14, 'n_estimators': 490, 'max_features': None, 'learning_rate': 0.00016338565381049014}. Best is trial 0 with value: 0.3713536470551035.
# [I 2024-04-10 21:37:06,972] Trial 3 finished with value: 0.9040743461686472 and parameters: {'max_depth': 14, 'n_estimators': 610, 'max_features': 'log2', 'learning_rate': 0.01004692266144022}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:07,138] Trial 4 finished with value: 0.9029691324617998 and parameters: {'max_depth': 14, 'n_estimators': 290, 'max_features': 'sqrt', 'learning_rate': 0.014687787340012037}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:07,591] Trial 5 finished with value: 0.1226771459002453 and parameters: {'max_depth': 5, 'n_estimators': 10, 'max_features': None, 'learning_rate': 0.007957358125960927}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:07,709] Trial 6 finished with value: 0.7811810721767252 and parameters: {'max_depth': 5, 'n_estimators': 130, 'max_features': None, 'learning_rate': 0.008718722224630686}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:08,156] Trial 7 finished with value: 0.025517732443655333 and parameters: {'max_depth': 14, 'n_estimators': 830, 'max_features': 'sqrt', 'learning_rate': 2.0437868855719838e-05}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:08,389] Trial 8 finished with value: 0.06288425829534738 and parameters: {'max_depth': 8, 'n_estimators': 410, 'max_features': 'log2', 'learning_rate': 9.605468120448523e-05}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:08,581] Trial 9 finished with value: 0.023403648626271905 and parameters: {'max_depth': 11, 'n_estimators': 290, 'max_features': 'log2', 'learning_rate': 5.363179231188447e-05}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:09,218] Trial 10 finished with value: 0.8837032033763514 and parameters: {'max_depth': 2, 'n_estimators': 690, 'max_features': 'log2', 'learning_rate': 0.06857643562428535}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:09,588] Trial 11 finished with value: 0.9025130222414027 and parameters: {'max_depth': 14, 'n_estimators': 670, 'max_features': 'sqrt', 'learning_rate': 0.0062016217698541674}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:09,768] Trial 12 finished with value: 0.8998556773872569 and parameters: {'max_depth': 11, 'n_estimators': 610, 'max_features': 'sqrt', 'learning_rate': 0.07195988555261625}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:09,905] Trial 13 finished with value: 0.505815929803467 and parameters: {'max_depth': 14, 'n_estimators': 230, 'max_features': 'sqrt', 'learning_rate': 0.0018495053165737568}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:10,389] Trial 14 finished with value: 0.901674677381877 and parameters: {'max_depth': 11, 'n_estimators': 990, 'max_features': 'log2', 'learning_rate': 0.02663230278036297}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:10,746] Trial 15 finished with value: 0.7195667767660354 and parameters: {'max_depth': 14, 'n_estimators': 510, 'max_features': 'log2', 'learning_rate': 0.001597500018312802}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:11,031] Trial 16 finished with value: 0.9005282211059781 and parameters: {'max_depth': 11, 'n_estimators': 550, 'max_features': 'sqrt', 'learning_rate': 0.027231789484896938}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:11,123] Trial 17 finished with value: 0.1511725065179573 and parameters: {'max_depth': 8, 'n_estimators': 150, 'max_features': 'log2', 'learning_rate': 0.0006430522765608474}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:11,340] Trial 18 finished with value: 0.8747810421452521 and parameters: {'max_depth': 14, 'n_estimators': 410, 'max_features': 'sqrt', 'learning_rate': 0.004508379730258515}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:11,658] Trial 19 finished with value: 0.8832510981425222 and parameters: {'max_depth': 2, 'n_estimators': 810, 'max_features': None, 'learning_rate': 0.021622524184497498}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:11,877] Trial 20 finished with value: 0.8707712139035074 and parameters: {'max_depth': 5, 'n_estimators': 730, 'max_features': 'sqrt', 'learning_rate': 0.0029505700835277876}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:12,211] Trial 21 finished with value: 0.902614296635646 and parameters: {'max_depth': 14, 'n_estimators': 630, 'max_features': 'sqrt', 'learning_rate': 0.012293216527192933}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:12,515] Trial 22 finished with value: 0.9025623822742798 and parameters: {'max_depth': 14, 'n_estimators': 590, 'max_features': 'sqrt', 'learning_rate': 0.014125913523315032}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:12,725] Trial 23 finished with value: 0.9003751258681773 and parameters: {'max_depth': 11, 'n_estimators': 430, 'max_features': 'sqrt', 'learning_rate': 0.03975621380178108}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:12,901] Trial 24 finished with value: 0.9020600482582918 and parameters: {'max_depth': 14, 'n_estimators': 330, 'max_features': 'sqrt', 'learning_rate': 0.013866817986686635}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:13,367] Trial 25 finished with value: 0.9015287952816031 and parameters: {'max_depth': 11, 'n_estimators': 750, 'max_features': 'log2', 'learning_rate': 0.004105431671557208}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:13,687] Trial 26 finished with value: 0.5575272978985086 and parameters: {'max_depth': 14, 'n_estimators': 610, 'max_features': 'sqrt', 'learning_rate': 0.0008180658076453754}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:13,812] Trial 27 finished with value: 0.8942912088778693 and parameters: {'max_depth': 11, 'n_estimators': 470, 'max_features': 'sqrt', 'learning_rate': 0.09898217819710546}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:14,107] Trial 28 finished with value: 0.5628765595463268 and parameters: {'max_depth': 14, 'n_estimators': 210, 'max_features': None, 'learning_rate': 0.0023439369685216848}. Best is trial 3 with value: 0.9040743461686472.
# [I 2024-04-10 21:37:14,671] Trial 29 finished with value: 0.5578606505401583 and parameters: {'max_depth': 11, 'n_estimators': 910, 'max_features': 'log2', 'learning_rate': 0.0005418554297232622}. Best is trial 3 with value: 0.9040743461686472.
# {'max_depth': 14,
#  'n_estimators': 610,
#  'max_features': 'log2',
#  'learning_rate': 0.01004692266144022}

# %%
# Обучаем модель с найденными гиперпараметрами

model_gb_optuna = GradientBoostingRegressor(**study_gb.best_params)
model_gb_optuna.fit(X_train, y_train)
preds_gb_optuna = model_gb_optuna.predict(X_test)
r2_score(y_test, preds_gb_optuna)
# Out:
# 0.9309777751868691

# %%
# Сначала используем модель классического град бустинга - подберем гиперпараметры GridSearch

# Сначала подберем два основных гиперпараметра для ансамблей - количество базовых деревьев и макс глубина
params = {'max_depth': np.arange(3,15,3),
         'n_estimators': np.arange(10, 300, 10)}

gb_gs = GridSearchCV(GradientBoostingRegressor(random_state=42), params, cv=3, scoring='r2', verbose=2)
gb_gs.fit(X_train, y_train)

gb_gs.best_score_, gb_gs.best_estimator_
# Out:
# Fitting 3 folds for each of 116 candidates, totalling 348 fits
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=30; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=30; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=30; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=50; total time=   0.0s
# [CV] END .......................max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=80; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=80; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=80; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=90; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=90; total time=   0.1s
# [CV] END .......................max_depth=3, n_estimators=90; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=110; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=110; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=110; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=120; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=120; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=120; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=130; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=130; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=130; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=140; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=140; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=140; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=150; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=150; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=150; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=160; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=160; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=160; total time=   0.1s
# [CV] END ......................max_depth=3, n_estimators=170; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=170; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=170; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=180; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=180; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=180; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=190; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=190; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=190; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=200; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=200; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=200; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=210; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=210; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=210; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=220; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=220; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=220; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=230; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=230; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=230; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=240; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=240; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=240; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=250; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=250; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=250; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=260; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=260; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=260; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=270; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=270; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=270; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=280; total time=   0.3s
# [CV] END ......................max_depth=3, n_estimators=280; total time=   0.3s
# [CV] END ......................max_depth=3, n_estimators=280; total time=   0.2s
# [CV] END ......................max_depth=3, n_estimators=290; total time=   0.3s
# [CV] END ......................max_depth=3, n_estimators=290; total time=   0.3s
# [CV] END ......................max_depth=3, n_estimators=290; total time=   0.3s
# [CV] END .......................max_depth=6, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=30; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=30; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=30; total time=   0.0s
# [CV] END .......................max_depth=6, n_estimators=40; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=40; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=40; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=80; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=80; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=80; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=90; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=90; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=90; total time=   0.1s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=110; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=110; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=110; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=120; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=120; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=120; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=130; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=130; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=130; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=140; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=140; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=140; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=150; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=150; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=150; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=160; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=160; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=160; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=170; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=170; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=170; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=180; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=180; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=180; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=190; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=190; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=190; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=200; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=200; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=200; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=210; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=210; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=210; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=220; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=220; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=220; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=230; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=230; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=230; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=240; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=240; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=240; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=250; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=250; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=250; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=260; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=260; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=260; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=270; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=270; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=270; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=280; total time=   0.5s
# [CV] END ......................max_depth=6, n_estimators=280; total time=   0.5s
# [CV] END ......................max_depth=6, n_estimators=280; total time=   0.5s
# [CV] END ......................max_depth=6, n_estimators=290; total time=   0.5s
# [CV] END ......................max_depth=6, n_estimators=290; total time=   0.5s
# [CV] END ......................max_depth=6, n_estimators=290; total time=   0.5s
# [CV] END .......................max_depth=9, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=9, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=9, n_estimators=10; total time=   0.0s
# [CV] END .......................max_depth=9, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=9, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=9, n_estimators=20; total time=   0.0s
# [CV] END .......................max_depth=9, n_estimators=30; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=30; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=30; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=40; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=40; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=40; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=60; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=70; total time=   0.1s
# [CV] END .......................max_depth=9, n_estimators=80; total time=   0.2s
# [CV] END .......................max_depth=9, n_estimators=80; total time=   0.2s
# [CV] END .......................max_depth=9, n_estimators=80; total time=   0.2s
# [CV] END .......................max_depth=9, n_estimators=90; total time=   0.2s
# [CV] END .......................max_depth=9, n_estimators=90; total time=   0.2s
# [CV] END .......................max_depth=9, n_estimators=90; total time=   0.2s
# [CV] END ......................max_depth=9, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=9, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=9, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=9, n_estimators=110; total time=   0.2s
# [CV] END ......................max_depth=9, n_estimators=110; total time=   0.2s
# [CV] END ......................max_depth=9, n_estimators=110; total time=   0.2s
# [CV] END ......................max_depth=9, n_estimators=120; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=120; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=120; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=130; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=130; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=130; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=140; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=140; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=140; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=150; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=150; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=150; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=160; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=160; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=160; total time=   0.3s
# [CV] END ......................max_depth=9, n_estimators=170; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=170; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=170; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=180; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=180; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=180; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=190; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=190; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=190; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=200; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=200; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=200; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=210; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=210; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=210; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=220; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=220; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=220; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=230; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=230; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=230; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=240; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=240; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=240; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=250; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=250; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=250; total time=   0.6s
# [CV] END ......................max_depth=9, n_estimators=260; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=260; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=260; total time=   0.6s
# [CV] END ......................max_depth=9, n_estimators=270; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=270; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=270; total time=   0.6s
# [CV] END ......................max_depth=9, n_estimators=280; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=280; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=280; total time=   0.6s
# [CV] END ......................max_depth=9, n_estimators=290; total time=   0.4s
# [CV] END ......................max_depth=9, n_estimators=290; total time=   0.5s
# [CV] END ......................max_depth=9, n_estimators=290; total time=   0.6s
# [CV] END ......................max_depth=12, n_estimators=10; total time=   0.0s
# [CV] END ......................max_depth=12, n_estimators=10; total time=   0.0s
# [CV] END ......................max_depth=12, n_estimators=10; total time=   0.0s
# [CV] END ......................max_depth=12, n_estimators=20; total time=   0.0s
# [CV] END ......................max_depth=12, n_estimators=20; total time=   0.0s
# [CV] END ......................max_depth=12, n_estimators=20; total time=   0.0s
# [CV] END ......................max_depth=12, n_estimators=30; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=30; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=30; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=40; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=40; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=40; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=60; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=60; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=60; total time=   0.1s
# [CV] END ......................max_depth=12, n_estimators=70; total time=   0.2s
# [CV] END ......................max_depth=12, n_estimators=70; total time=   0.2s
# [CV] END ......................max_depth=12, n_estimators=70; total time=   0.2s
# [CV] END ......................max_depth=12, n_estimators=80; total time=   0.2s
# [CV] END ......................max_depth=12, n_estimators=80; total time=   0.2s
# [CV] END ......................max_depth=12, n_estimators=80; total time=   0.2s
# [CV] END ......................max_depth=12, n_estimators=90; total time=   0.2s
# [CV] END ......................max_depth=12, n_estimators=90; total time=   0.2s
# [CV] END ......................max_depth=12, n_estimators=90; total time=   0.2s
# [CV] END .....................max_depth=12, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=12, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=12, n_estimators=100; total time=   0.2s
# [CV] END .....................max_depth=12, n_estimators=110; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=110; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=110; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=120; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=120; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=120; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=130; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=130; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=130; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=140; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=140; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=140; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=150; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=150; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=150; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=160; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=160; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=160; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=170; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=170; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=170; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=180; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=180; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=180; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=190; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=190; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=190; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=200; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=200; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=200; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=210; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=210; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=210; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=220; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=220; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=220; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=230; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=230; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=230; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=240; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=240; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=240; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=250; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=250; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=250; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=260; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=260; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=260; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=270; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=270; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=270; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=280; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=280; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=280; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=290; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=290; total time=   0.4s
# [CV] END .....................max_depth=12, n_estimators=290; total time=   0.4s
# (0.9023309095156579,
#  GradientBoostingRegressor(n_estimators=290, random_state=42))

# %%
# Поберем еще два важный гиперпараметра - max_features - количество признаков, отбираемых для построения предиката
# Из исходного множества признаков
# И learning_rate - шаг градиентного спуска

params_2 = {'max_features': [None, 'log2', 'sqrt'],
           'learning_rate': [0.0001, 0.001, 0.01, 0.1]}

gb_gs_2 = GridSearchCV(GradientBoostingRegressor(**gb_gs.best_params_), params_2, cv=3, scoring='r2', verbose=2)
gb_gs_2.fit(X_train, y_train)

gb_gs_2.best_score_, gb_gs_2.best_estimator_
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END ............learning_rate=0.0001, max_features=None; total time=   0.3s
# [CV] END ............learning_rate=0.0001, max_features=None; total time=   0.3s
# [CV] END ............learning_rate=0.0001, max_features=None; total time=   0.3s
# [CV] END ............learning_rate=0.0001, max_features=log2; total time=   0.1s
# [CV] END ............learning_rate=0.0001, max_features=log2; total time=   0.1s
# [CV] END ............learning_rate=0.0001, max_features=log2; total time=   0.1s
# [CV] END ............learning_rate=0.0001, max_features=sqrt; total time=   0.1s
# [CV] END ............learning_rate=0.0001, max_features=sqrt; total time=   0.1s
# [CV] END ............learning_rate=0.0001, max_features=sqrt; total time=   0.1s
# [CV] END .............learning_rate=0.001, max_features=None; total time=   0.3s
# [CV] END .............learning_rate=0.001, max_features=None; total time=   0.3s
# [CV] END .............learning_rate=0.001, max_features=None; total time=   0.3s
# [CV] END .............learning_rate=0.001, max_features=log2; total time=   0.1s
# [CV] END .............learning_rate=0.001, max_features=log2; total time=   0.1s
# [CV] END .............learning_rate=0.001, max_features=log2; total time=   0.1s
# [CV] END .............learning_rate=0.001, max_features=sqrt; total time=   0.1s
# [CV] END .............learning_rate=0.001, max_features=sqrt; total time=   0.1s
# [CV] END .............learning_rate=0.001, max_features=sqrt; total time=   0.1s
# [CV] END ..............learning_rate=0.01, max_features=None; total time=   0.3s
# [CV] END ..............learning_rate=0.01, max_features=None; total time=   0.3s
# [CV] END ..............learning_rate=0.01, max_features=None; total time=   0.3s
# [CV] END ..............learning_rate=0.01, max_features=log2; total time=   0.1s
# [CV] END ..............learning_rate=0.01, max_features=log2; total time=   0.1s
# [CV] END ..............learning_rate=0.01, max_features=log2; total time=   0.1s
# [CV] END ..............learning_rate=0.01, max_features=sqrt; total time=   0.1s
# [CV] END ..............learning_rate=0.01, max_features=sqrt; total time=   0.1s
# [CV] END ..............learning_rate=0.01, max_features=sqrt; total time=   0.1s
# [CV] END ...............learning_rate=0.1, max_features=None; total time=   0.3s
# [CV] END ...............learning_rate=0.1, max_features=None; total time=   0.3s
# [CV] END ...............learning_rate=0.1, max_features=None; total time=   0.3s
# [CV] END ...............learning_rate=0.1, max_features=log2; total time=   0.1s
# [CV] END ...............learning_rate=0.1, max_features=log2; total time=   0.1s
# [CV] END ...............learning_rate=0.1, max_features=log2; total time=   0.1s
# [CV] END ...............learning_rate=0.1, max_features=sqrt; total time=   0.1s
# [CV] END ...............learning_rate=0.1, max_features=sqrt; total time=   0.1s
# [CV] END ...............learning_rate=0.1, max_features=sqrt; total time=   0.1s
# (0.9081234444267384,
#  GradientBoostingRegressor(max_features='log2', n_estimators=290))

# %%
# Обучим модель

model_gb_grid_s = GradientBoostingRegressor(**gb_gs_2.best_params_)
model_gb_grid_s.fit(X_train, y_train)

preds_gb_grid_s = model_gb_grid_s.predict(X_test)
print(r2_score(y_test, preds_gb_grid_s))
# Out:
# 0.9216840878192623

# %%
y_test
# Out:
# 538    3.925
# 523    3.633
# 235    3.463
# 524    3.736
# 486    2.554
#        ...
# 421    2.691
# 382    2.488
# 519    2.589
# 404    2.453
# 115    1.725
# Name: NGK, Length: 170, dtype: object

# %%
# Отсортируем полученные значения по optuna для визуализации предсказаний

depth_values = depth.values.astype('float64')
y_test_for_plot = y_test.values.astype('float64')

plot_test_arr = list(zip(depth_values, y_test_for_plot))
plot_sorted_arr = sorted(plot_test_arr, key=lambda x: x[0])
depth_plotting = [i[0] for i in plot_sorted_arr]
y_test_plotting = [i[1] for i in plot_sorted_arr]
depth_plotting
# Out:
# [2790.0,
#  2790.4,
#  2791.2,
#  2791.8,
#  2792.0,
#  2792.2,
#  2793.0,
#  2793.6,
#  2794.4,
#  2796.0,
#  2796.6,
#  2797.8,
#  2799.2,
#  2800.8,
#  2801.0,
#  2802.6,
#  2803.6,
#  2803.8,
#  2804.0,
#  2804.4,
#  2804.6,
#  2805.0,
#  2805.2,
#  2805.4,
#  2805.6,
#  2805.8,
#  2806.2,
#  2806.4,
#  2806.6,
#  2806.8,
#  2807.2,
#  2807.6,
#  2807.8,
#  2808.0,
#  2808.6,
#  2810.8,
#  2811.4,
#  2812.2,
#  2812.4,
#  2813.4,
#  2814.0,
#  2814.2,
#  2815.4,
#  2816.8,
#  2817.0,
#  2818.0,
#  2818.6,
#  2819.4,
#  2819.6,
#  2820.2,
#  2820.4,
#  2821.2,
#  2821.6,
#  2822.4,
#  2823.4,
#  2823.8,
#  2824.2,
#  2826.0,
#  2826.2,
#  2827.2,
#  2827.6,
#  2827.8,
#  2828.4,
#  2829.2,
#  2829.8,
#  2830.6,
#  2835.6,
#  2835.8,
#  2836.6,
#  2836.8,
#  2837.0,
#  2837.2,
#  2838.6,
#  2839.4,
#  2840.6,
#  2841.2,
#  2841.8,
#  2842.6,
#  2844.4,
#  2844.6,
#  2844.8,
#  2845.0,
#  2846.0,
#  2846.4,
#  2847.2,
#  2847.6,
#  2848.0,
#  2849.2,
#  2850.0,
#  2851.0,
#  2852.2,
#  2853.0,
#  2853.2,
#  2854.2,
#  2857.0,
#  2857.2,
#  2858.2,
#  2858.6,
#  2859.2,
#  2859.4,
#  2859.8,
#  2860.6,
#  2860.8,
#  2861.2,
#  2861.8,
#  2862.2,
#  2862.6,
#  2863.0,
#  2864.8,
#  2865.4,
#  2865.6,
#  2866.2,
#  2867.8,
#  2869.0,
#  2869.8,
#  2870.4,
#  2871.2,
#  2871.8,
#  2872.6,
#  2873.0,
#  2874.0,
#  2875.4,
#  2875.6,
#  2875.8,
#  2876.4,
#  2877.0,
#  2877.4,
#  2877.8,
#  2878.0,
#  2878.2,
#  2879.0,
#  2880.2,
#  2882.8,
#  2883.8,
#  2884.6,
#  2885.0,
#  2885.6,
#  2886.4,
#  2888.6,
#  2889.6,
#  2890.4,
#  2892.0,
#  2892.6,
#  2893.8,
#  2894.0,
#  2894.6,
#  2895.6,
#  2896.0,
#  2898.0,
#  2898.6,
#  2899.2,
#  2899.4,
#  2899.6,
#  2900.2,
#  2901.2,
#  2901.8,
#  2902.0,
#  2902.4,
#  2903.0,
#  2903.4,
#  2903.8,
#  2904.0,
#  2904.4,
#  2905.2,
#  2905.6,
#  2906.4,
#  2906.6,
#  2907.0,
#  2907.2,
#  2907.8]

# %%
# Тут непосредственно предсказания

plot_preds_arr = list(zip(depth_values, preds_gb_optuna))
plot_sorted_preds = sorted(plot_preds_arr, key=lambda x: x[0])
depth_plotting = [i[0] for i in plot_sorted_preds]
preds_plotting = [i[1] for i in plot_sorted_preds]
depth_plotting
# Out:
# [2790.0,
#  2790.4,
#  2791.2,
#  2791.8,
#  2792.0,
#  2792.2,
#  2793.0,
#  2793.6,
#  2794.4,
#  2796.0,
#  2796.6,
#  2797.8,
#  2799.2,
#  2800.8,
#  2801.0,
#  2802.6,
#  2803.6,
#  2803.8,
#  2804.0,
#  2804.4,
#  2804.6,
#  2805.0,
#  2805.2,
#  2805.4,
#  2805.6,
#  2805.8,
#  2806.2,
#  2806.4,
#  2806.6,
#  2806.8,
#  2807.2,
#  2807.6,
#  2807.8,
#  2808.0,
#  2808.6,
#  2810.8,
#  2811.4,
#  2812.2,
#  2812.4,
#  2813.4,
#  2814.0,
#  2814.2,
#  2815.4,
#  2816.8,
#  2817.0,
#  2818.0,
#  2818.6,
#  2819.4,
#  2819.6,
#  2820.2,
#  2820.4,
#  2821.2,
#  2821.6,
#  2822.4,
#  2823.4,
#  2823.8,
#  2824.2,
#  2826.0,
#  2826.2,
#  2827.2,
#  2827.6,
#  2827.8,
#  2828.4,
#  2829.2,
#  2829.8,
#  2830.6,
#  2835.6,
#  2835.8,
#  2836.6,
#  2836.8,
#  2837.0,
#  2837.2,
#  2838.6,
#  2839.4,
#  2840.6,
#  2841.2,
#  2841.8,
#  2842.6,
#  2844.4,
#  2844.6,
#  2844.8,
#  2845.0,
#  2846.0,
#  2846.4,
#  2847.2,
#  2847.6,
#  2848.0,
#  2849.2,
#  2850.0,
#  2851.0,
#  2852.2,
#  2853.0,
#  2853.2,
#  2854.2,
#  2857.0,
#  2857.2,
#  2858.2,
#  2858.6,
#  2859.2,
#  2859.4,
#  2859.8,
#  2860.6,
#  2860.8,
#  2861.2,
#  2861.8,
#  2862.2,
#  2862.6,
#  2863.0,
#  2864.8,
#  2865.4,
#  2865.6,
#  2866.2,
#  2867.8,
#  2869.0,
#  2869.8,
#  2870.4,
#  2871.2,
#  2871.8,
#  2872.6,
#  2873.0,
#  2874.0,
#  2875.4,
#  2875.6,
#  2875.8,
#  2876.4,
#  2877.0,
#  2877.4,
#  2877.8,
#  2878.0,
#  2878.2,
#  2879.0,
#  2880.2,
#  2882.8,
#  2883.8,
#  2884.6,
#  2885.0,
#  2885.6,
#  2886.4,
#  2888.6,
#  2889.6,
#  2890.4,
#  2892.0,
#  2892.6,
#  2893.8,
#  2894.0,
#  2894.6,
#  2895.6,
#  2896.0,
#  2898.0,
#  2898.6,
#  2899.2,
#  2899.4,
#  2899.6,
#  2900.2,
#  2901.2,
#  2901.8,
#  2902.0,
#  2902.4,
#  2903.0,
#  2903.4,
#  2903.8,
#  2904.0,
#  2904.4,
#  2905.2,
#  2905.6,
#  2906.4,
#  2906.6,
#  2907.0,
#  2907.2,
#  2907.8]

# %%
# Визуализируем предсказания с гиперпараметрами по optuna - значения НГК по глубине

import matplotlib.pyplot as plt

plt.figure(figsize=(23, 6))

plt.plot(depth_plotting, y_test_plotting, color = 'b', label = 'Истинные значения НГК')
plt.plot(depth_plotting, preds_plotting, c = 'r', label = 'Спрогнозированные значения НГК')

plt.xlabel('Depth', fontsize = 15)
plt.ylabel('NGK', fontsize = 15)

plt.legend(fontsize = 15)
plt.grid()
plt.show()

# %%
# Оценим важность признаков 

# Получение важности признаков
feature_importance = model_gb_optuna.feature_importances_

# Получение названий признаков
feature_names = names

# Визуализация важности признаков
plt.figure(figsize=(10, 6))
plt.barh(range(len(feature_importance)), feature_importance, align='center')
plt.yticks(range(len(feature_importance)), feature_names)
plt.xlabel('Важность признака')
plt.ylabel('Признак')
plt.title('Важность признаков')
plt.show()

# %% [markdown]
# Feature Selection

# %%
# Попробуем оставить только 4 самых важный признака - PZ, PS, GK, GGKp

X = df.drop(['NGK', 'AK', 'BK', 'DS', 'IK'], axis = 1)
y = df['NGK']

# %%
np.random.seed(42)

#Делим на тест и трейн первый раз - достанем тестовую глубину
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# Берем глубину для визуализации предсказаний каротажа
depth = X_test.loc[:, 'Depth']
X = X.drop('Depth', axis=1)

#Делим на тест и трейн
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
def objective_GB_new(trial):
    
    max_depth = trial.suggest_int('max_depth', 2, 15, step = 3)
    n_estimators = trial.suggest_int('n_estimators', 10, 1000, 20)
    max_features = trial.suggest_categorical('max_features', [None, 'sqrt', 'log2'])
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log = True)
    
    score = cross_val_score(GradientBoostingRegressor(max_depth=max_depth, n_estimators=n_estimators,
                                                     max_features=max_features, learning_rate=learning_rate,
                                                     random_state=42),
                           X_train, y_train, cv=3, scoring='r2', n_jobs=-1).mean()
    return score

# %%
study_gb_new = optuna.create_study(direction='maximize')
study_gb_new.optimize(objective_GB_new, n_trials=30)
study_gb_new.best_params
# Out:
# [I 2024-04-10 21:48:07,518] A new study created in memory with name: no-name-9745192a-3b71-4fa0-838c-5ca7450a945d
# /Users/aleksandrbogdanov/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 15] and step=3, but the range is not divisible by `step`. It will be replaced by [2, 14].
#   warnings.warn(
# /var/folders/46/4js24d154nb0rgs9sp2kxk180000gn/T/ipykernel_23100/3853963294.py:4: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   n_estimators = trial.suggest_int('n_estimators', 10, 1000, 20)
# /Users/aleksandrbogdanov/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [10, 1000] and step=20, but the range is not divisible by `step`. It will be replaced by [10, 990].
#   warnings.warn(
# [I 2024-04-10 21:48:08,977] Trial 0 finished with value: 0.264961982303979 and parameters: {'max_depth': 5, 'n_estimators': 370, 'max_features': 'log2', 'learning_rate': 0.0005156471811947547}. Best is trial 0 with value: 0.264961982303979.
# [I 2024-04-10 21:48:09,586] Trial 1 finished with value: 0.30125693491461 and parameters: {'max_depth': 5, 'n_estimators': 150, 'max_features': 'log2', 'learning_rate': 0.0014871552709068883}. Best is trial 1 with value: 0.30125693491461.
# [I 2024-04-10 21:48:10,210] Trial 2 finished with value: 0.1798328700386014 and parameters: {'max_depth': 5, 'n_estimators': 330, 'max_features': None, 'learning_rate': 0.0003627752664496265}. Best is trial 1 with value: 0.30125693491461.
# [I 2024-04-10 21:48:10,346] Trial 3 finished with value: 0.48231541722797616 and parameters: {'max_depth': 8, 'n_estimators': 290, 'max_features': 'sqrt', 'learning_rate': 0.001377420387589081}. Best is trial 3 with value: 0.48231541722797616.
# [I 2024-04-10 21:48:10,774] Trial 4 finished with value: 0.14302772360377888 and parameters: {'max_depth': 14, 'n_estimators': 830, 'max_features': 'log2', 'learning_rate': 0.00010845745596879829}. Best is trial 3 with value: 0.48231541722797616.
# [I 2024-04-10 21:48:10,872] Trial 5 finished with value: 0.8738895683062852 and parameters: {'max_depth': 8, 'n_estimators': 230, 'max_features': 'sqrt', 'learning_rate': 0.04864793576070602}. Best is trial 5 with value: 0.8738895683062852.
# [I 2024-04-10 21:48:11,145] Trial 6 finished with value: 0.01780122286971057 and parameters: {'max_depth': 14, 'n_estimators': 510, 'max_features': 'log2', 'learning_rate': 2.4166627817703527e-05}. Best is trial 5 with value: 0.8738895683062852.
# [I 2024-04-10 21:48:11,611] Trial 7 finished with value: 0.8772726491952446 and parameters: {'max_depth': 11, 'n_estimators': 950, 'max_features': 'sqrt', 'learning_rate': 0.004821713106638771}. Best is trial 7 with value: 0.8772726491952446.
# [I 2024-04-10 21:48:12,202] Trial 8 finished with value: 0.8743202973050571 and parameters: {'max_depth': 2, 'n_estimators': 830, 'max_features': 'sqrt', 'learning_rate': 0.06420855272754938}. Best is trial 7 with value: 0.8772726491952446.
# [I 2024-04-10 21:48:12,452] Trial 9 finished with value: 0.8735797203091726 and parameters: {'max_depth': 11, 'n_estimators': 470, 'max_features': 'log2', 'learning_rate': 0.0054957301448811955}. Best is trial 7 with value: 0.8772726491952446.
# [I 2024-04-10 21:48:12,978] Trial 10 finished with value: 0.8274865850318022 and parameters: {'max_depth': 11, 'n_estimators': 670, 'max_features': None, 'learning_rate': 0.010014517119782814}. Best is trial 7 with value: 0.8772726491952446.
# [I 2024-04-10 21:48:13,169] Trial 11 finished with value: 0.8687182153913785 and parameters: {'max_depth': 2, 'n_estimators': 990, 'max_features': 'sqrt', 'learning_rate': 0.0879946393555658}. Best is trial 7 with value: 0.8772726491952446.
# [I 2024-04-10 21:48:13,360] Trial 12 finished with value: 0.8779683863288446 and parameters: {'max_depth': 2, 'n_estimators': 990, 'max_features': 'sqrt', 'learning_rate': 0.019010524471882336}. Best is trial 12 with value: 0.8779683863288446.
# [I 2024-04-10 21:48:13,875] Trial 13 finished with value: 0.8781611592444752 and parameters: {'max_depth': 11, 'n_estimators': 990, 'max_features': 'sqrt', 'learning_rate': 0.01036915198848828}. Best is trial 13 with value: 0.8781611592444752.
# [I 2024-04-10 21:48:14,210] Trial 14 finished with value: 0.8765622463216299 and parameters: {'max_depth': 11, 'n_estimators': 690, 'max_features': 'sqrt', 'learning_rate': 0.014589880576656299}. Best is trial 13 with value: 0.8781611592444752.
# [I 2024-04-10 21:48:14,368] Trial 15 finished with value: 0.878884798760148 and parameters: {'max_depth': 2, 'n_estimators': 850, 'max_features': 'sqrt', 'learning_rate': 0.01700752930381411}. Best is trial 15 with value: 0.878884798760148.
# [I 2024-04-10 21:48:14,736] Trial 16 finished with value: 0.8792700555304734 and parameters: {'max_depth': 8, 'n_estimators': 810, 'max_features': 'sqrt', 'learning_rate': 0.004365011571839921}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:15,065] Trial 17 finished with value: 0.8548407200199423 and parameters: {'max_depth': 5, 'n_estimators': 690, 'max_features': None, 'learning_rate': 0.0030088934366512233}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:15,083] Trial 18 finished with value: -0.001015251553194152 and parameters: {'max_depth': 8, 'n_estimators': 10, 'max_features': 'sqrt', 'learning_rate': 0.00016428241135870377}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:15,238] Trial 19 finished with value: 0.8777104841339717 and parameters: {'max_depth': 2, 'n_estimators': 830, 'max_features': 'sqrt', 'learning_rate': 0.03138589988898672}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:15,608] Trial 20 finished with value: 0.8076174406382535 and parameters: {'max_depth': 8, 'n_estimators': 570, 'max_features': None, 'learning_rate': 0.0024715296697146692}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:16,092] Trial 21 finished with value: 0.8782552384189852 and parameters: {'max_depth': 14, 'n_estimators': 890, 'max_features': 'sqrt', 'learning_rate': 0.008571427762889794}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:16,571] Trial 22 finished with value: 0.8783433144675783 and parameters: {'max_depth': 14, 'n_estimators': 870, 'max_features': 'sqrt', 'learning_rate': 0.007039219888103341}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:16,938] Trial 23 finished with value: 0.8761146580684421 and parameters: {'max_depth': 14, 'n_estimators': 750, 'max_features': 'sqrt', 'learning_rate': 0.024836326719164095}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:17,170] Trial 24 finished with value: 0.8774424375553481 and parameters: {'max_depth': 5, 'n_estimators': 770, 'max_features': 'sqrt', 'learning_rate': 0.0034690079104335763}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:17,430] Trial 25 finished with value: 0.47186822104471804 and parameters: {'max_depth': 8, 'n_estimators': 610, 'max_features': 'sqrt', 'learning_rate': 0.0006334891520976915}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:17,806] Trial 26 finished with value: 0.8741018167867435 and parameters: {'max_depth': 8, 'n_estimators': 890, 'max_features': 'sqrt', 'learning_rate': 0.034923922497149346}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:18,187] Trial 27 finished with value: 0.8771348653002994 and parameters: {'max_depth': 11, 'n_estimators': 770, 'max_features': 'sqrt', 'learning_rate': 0.00686174974044315}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:18,451] Trial 28 finished with value: 0.8486961282578996 and parameters: {'max_depth': 5, 'n_estimators': 890, 'max_features': 'sqrt', 'learning_rate': 0.001988778178664494}. Best is trial 16 with value: 0.8792700555304734.
# [I 2024-04-10 21:48:18,573] Trial 29 finished with value: 0.3920668399006477 and parameters: {'max_depth': 2, 'n_estimators': 430, 'max_features': None, 'learning_rate': 0.0008978607395495354}. Best is trial 16 with value: 0.8792700555304734.
# {'max_depth': 8,
#  'n_estimators': 810,
#  'max_features': 'sqrt',
#  'learning_rate': 0.004365011571839921}

# %%
model_gb_optuna_new = GradientBoostingRegressor(**study_gb_new.best_params)
model_gb_optuna_new.fit(X_train, y_train)
preds_gb_optuna_new = model_gb_optuna_new.predict(X_test)
r2_score(y_test, preds_gb_optuna_new)
# Out:
# 0.911981160994626

# %%
# Качество уменьшилось совсем незначительно, хотя признаков осталось всего 4

# %%
# Out:
#       GGKp      GK       PS      PZ
# 538  2.481   5.464  112.100   21.11
# 523  2.544   5.559  110.754   17.11
# 235  2.385   4.002   34.020   28.56
# 524  2.584   6.201  112.624   17.98
# 486  2.260   6.625  117.111    9.37
# ..     ...     ...      ...     ...
# 421  2.553   7.719  124.029    7.30
# 382  2.562   6.742  122.982    6.92
# 519  2.480   7.540  115.952   15.56
# 404  2.651   6.670  123.132    6.18
# 115  2.121  37.298  121.524  123.87
#
# [170 rows x 4 columns]

# %%
# Отсортируем полученные значения по optuna для визуализации предсказаний

depth_values = depth.values.astype('float64')
y_test_for_plot = y_test.values.astype('float64')

plot_test_arr = list(zip(depth_values, y_test_for_plot))
plot_sorted_arr = sorted(plot_test_arr, key=lambda x: x[0])
depth_plotting = [i[0] for i in plot_sorted_arr]
y_test_plotting = [i[1] for i in plot_sorted_arr]
depth_plotting
# Out:
# [2790.0,
#  2790.4,
#  2791.2,
#  2791.8,
#  2792.0,
#  2792.2,
#  2793.0,
#  2793.6,
#  2794.4,
#  2796.0,
#  2796.6,
#  2797.8,
#  2799.2,
#  2800.8,
#  2801.0,
#  2802.6,
#  2803.6,
#  2803.8,
#  2804.0,
#  2804.4,
#  2804.6,
#  2805.0,
#  2805.2,
#  2805.4,
#  2805.6,
#  2805.8,
#  2806.2,
#  2806.4,
#  2806.6,
#  2806.8,
#  2807.2,
#  2807.6,
#  2807.8,
#  2808.0,
#  2808.6,
#  2810.8,
#  2811.4,
#  2812.2,
#  2812.4,
#  2813.4,
#  2814.0,
#  2814.2,
#  2815.4,
#  2816.8,
#  2817.0,
#  2818.0,
#  2818.6,
#  2819.4,
#  2819.6,
#  2820.2,
#  2820.4,
#  2821.2,
#  2821.6,
#  2822.4,
#  2823.4,
#  2823.8,
#  2824.2,
#  2826.0,
#  2826.2,
#  2827.2,
#  2827.6,
#  2827.8,
#  2828.4,
#  2829.2,
#  2829.8,
#  2830.6,
#  2835.6,
#  2835.8,
#  2836.6,
#  2836.8,
#  2837.0,
#  2837.2,
#  2838.6,
#  2839.4,
#  2840.6,
#  2841.2,
#  2841.8,
#  2842.6,
#  2844.4,
#  2844.6,
#  2844.8,
#  2845.0,
#  2846.0,
#  2846.4,
#  2847.2,
#  2847.6,
#  2848.0,
#  2849.2,
#  2850.0,
#  2851.0,
#  2852.2,
#  2853.0,
#  2853.2,
#  2854.2,
#  2857.0,
#  2857.2,
#  2858.2,
#  2858.6,
#  2859.2,
#  2859.4,
#  2859.8,
#  2860.6,
#  2860.8,
#  2861.2,
#  2861.8,
#  2862.2,
#  2862.6,
#  2863.0,
#  2864.8,
#  2865.4,
#  2865.6,
#  2866.2,
#  2867.8,
#  2869.0,
#  2869.8,
#  2870.4,
#  2871.2,
#  2871.8,
#  2872.6,
#  2873.0,
#  2874.0,
#  2875.4,
#  2875.6,
#  2875.8,
#  2876.4,
#  2877.0,
#  2877.4,
#  2877.8,
#  2878.0,
#  2878.2,
#  2879.0,
#  2880.2,
#  2882.8,
#  2883.8,
#  2884.6,
#  2885.0,
#  2885.6,
#  2886.4,
#  2888.6,
#  2889.6,
#  2890.4,
#  2892.0,
#  2892.6,
#  2893.8,
#  2894.0,
#  2894.6,
#  2895.6,
#  2896.0,
#  2898.0,
#  2898.6,
#  2899.2,
#  2899.4,
#  2899.6,
#  2900.2,
#  2901.2,
#  2901.8,
#  2902.0,
#  2902.4,
#  2903.0,
#  2903.4,
#  2903.8,
#  2904.0,
#  2904.4,
#  2905.2,
#  2905.6,
#  2906.4,
#  2906.6,
#  2907.0,
#  2907.2,
#  2907.8]

# %%
# Тут непосредственно предсказания

plot_preds_arr = list(zip(depth_values, preds_gb_optuna_new))
plot_sorted_preds = sorted(plot_preds_arr, key=lambda x: x[0])
depth_plotting = [i[0] for i in plot_sorted_preds]
preds_plotting = [i[1] for i in plot_sorted_preds]
depth_plotting
# Out:
# [2790.0,
#  2790.4,
#  2791.2,
#  2791.8,
#  2792.0,
#  2792.2,
#  2793.0,
#  2793.6,
#  2794.4,
#  2796.0,
#  2796.6,
#  2797.8,
#  2799.2,
#  2800.8,
#  2801.0,
#  2802.6,
#  2803.6,
#  2803.8,
#  2804.0,
#  2804.4,
#  2804.6,
#  2805.0,
#  2805.2,
#  2805.4,
#  2805.6,
#  2805.8,
#  2806.2,
#  2806.4,
#  2806.6,
#  2806.8,
#  2807.2,
#  2807.6,
#  2807.8,
#  2808.0,
#  2808.6,
#  2810.8,
#  2811.4,
#  2812.2,
#  2812.4,
#  2813.4,
#  2814.0,
#  2814.2,
#  2815.4,
#  2816.8,
#  2817.0,
#  2818.0,
#  2818.6,
#  2819.4,
#  2819.6,
#  2820.2,
#  2820.4,
#  2821.2,
#  2821.6,
#  2822.4,
#  2823.4,
#  2823.8,
#  2824.2,
#  2826.0,
#  2826.2,
#  2827.2,
#  2827.6,
#  2827.8,
#  2828.4,
#  2829.2,
#  2829.8,
#  2830.6,
#  2835.6,
#  2835.8,
#  2836.6,
#  2836.8,
#  2837.0,
#  2837.2,
#  2838.6,
#  2839.4,
#  2840.6,
#  2841.2,
#  2841.8,
#  2842.6,
#  2844.4,
#  2844.6,
#  2844.8,
#  2845.0,
#  2846.0,
#  2846.4,
#  2847.2,
#  2847.6,
#  2848.0,
#  2849.2,
#  2850.0,
#  2851.0,
#  2852.2,
#  2853.0,
#  2853.2,
#  2854.2,
#  2857.0,
#  2857.2,
#  2858.2,
#  2858.6,
#  2859.2,
#  2859.4,
#  2859.8,
#  2860.6,
#  2860.8,
#  2861.2,
#  2861.8,
#  2862.2,
#  2862.6,
#  2863.0,
#  2864.8,
#  2865.4,
#  2865.6,
#  2866.2,
#  2867.8,
#  2869.0,
#  2869.8,
#  2870.4,
#  2871.2,
#  2871.8,
#  2872.6,
#  2873.0,
#  2874.0,
#  2875.4,
#  2875.6,
#  2875.8,
#  2876.4,
#  2877.0,
#  2877.4,
#  2877.8,
#  2878.0,
#  2878.2,
#  2879.0,
#  2880.2,
#  2882.8,
#  2883.8,
#  2884.6,
#  2885.0,
#  2885.6,
#  2886.4,
#  2888.6,
#  2889.6,
#  2890.4,
#  2892.0,
#  2892.6,
#  2893.8,
#  2894.0,
#  2894.6,
#  2895.6,
#  2896.0,
#  2898.0,
#  2898.6,
#  2899.2,
#  2899.4,
#  2899.6,
#  2900.2,
#  2901.2,
#  2901.8,
#  2902.0,
#  2902.4,
#  2903.0,
#  2903.4,
#  2903.8,
#  2904.0,
#  2904.4,
#  2905.2,
#  2905.6,
#  2906.4,
#  2906.6,
#  2907.0,
#  2907.2,
#  2907.8]

# %%
# Визуализируем предсказания с гиперпараметрами по optuna - значения НГК по глубине

import matplotlib.pyplot as plt

plt.figure(figsize=(23, 6))

plt.plot(depth_plotting, y_test_plotting, color = 'b', label = 'Истинные значения НГК')
plt.plot(depth_plotting, preds_plotting, c = 'r', label = 'Спрогнозированные значения НГК')

plt.xlabel('Depth', fontsize = 15)
plt.ylabel('NGK', fontsize = 15)

plt.legend(fontsize = 15)
plt.grid()
plt.show()

# %% [markdown]
# Попробуем улучшить предсказания, возьмем в качестве модели XGBoost

# %%
# Catboost и LGBM брать не будем, качество будет примерно одинаковое + нет категориальных признаков

# %%
def objective_XGB(trial):
    
    max_depth = trial.suggest_int('max_depth', 2, 15, step = 3)
    n_estimators = trial.suggest_int('n_estimators', 10, 1000, 20)
    max_leaves = trial.suggest_int('max_leaves', 1, 15)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log = True)
    
    score = cross_val_score(XGBRegressor(max_depth=max_depth, n_estimators=n_estimators,
                                                     max_leaves = max_leaves, learning_rate=learning_rate,
                                                     random_state=42),
                           X_train, y_train, cv=3, scoring='r2', n_jobs=-1).mean()
    return score

# %%
study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_XGB, n_trials=30)
study_xgb.best_params
# Out:
# [I 2024-04-10 21:55:18,785] A new study created in memory with name: no-name-0ca9ca93-34e0-4e66-8dcc-5db0b79c9b4b
# /Users/aleksandrbogdanov/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [2, 15] and step=3, but the range is not divisible by `step`. It will be replaced by [2, 14].
#   warnings.warn(
# /var/folders/46/4js24d154nb0rgs9sp2kxk180000gn/T/ipykernel_23100/3944823240.py:4: FutureWarning: suggest_int() got {'step'} as positional arguments but they were expected to be given as keyword arguments.
#   n_estimators = trial.suggest_int('n_estimators', 10, 1000, 20)
# /Users/aleksandrbogdanov/anaconda3/lib/python3.11/site-packages/optuna/distributions.py:700: UserWarning: The distribution is specified by [10, 1000] and step=20, but the range is not divisible by `step`. It will be replaced by [10, 990].
#   warnings.warn(
# [I 2024-04-10 21:55:20,137] Trial 0 finished with value: 0.11105894715660085 and parameters: {'max_depth': 14, 'n_estimators': 570, 'max_leaves': 12, 'learning_rate': 0.00013656140590000701}. Best is trial 0 with value: 0.11105894715660085.
# [I 2024-04-10 21:55:20,680] Trial 1 finished with value: 0.8744435994835267 and parameters: {'max_depth': 14, 'n_estimators': 750, 'max_leaves': 14, 'learning_rate': 0.00483475422468401}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:21,113] Trial 2 finished with value: 0.645212180316039 and parameters: {'max_depth': 11, 'n_estimators': 450, 'max_leaves': 3, 'learning_rate': 0.0027645330984473254}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:21,557] Trial 3 finished with value: 0.09002423888602436 and parameters: {'max_depth': 14, 'n_estimators': 310, 'max_leaves': 13, 'learning_rate': 0.00020179549361448157}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:22,014] Trial 4 finished with value: 0.7716731633225744 and parameters: {'max_depth': 5, 'n_estimators': 310, 'max_leaves': 13, 'learning_rate': 0.004072218886288009}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:22,063] Trial 5 finished with value: -0.003913726791213564 and parameters: {'max_depth': 8, 'n_estimators': 870, 'max_leaves': 1, 'learning_rate': 0.008242016384204501}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:22,153] Trial 6 finished with value: 0.8697774459459892 and parameters: {'max_depth': 14, 'n_estimators': 810, 'max_leaves': 7, 'learning_rate': 0.049718590801334915}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:22,161] Trial 7 finished with value: 0.8269100372228063 and parameters: {'max_depth': 2, 'n_estimators': 30, 'max_leaves': 7, 'learning_rate': 0.09582447645924637}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:22,212] Trial 8 finished with value: 0.7625629117435291 and parameters: {'max_depth': 2, 'n_estimators': 750, 'max_leaves': 14, 'learning_rate': 0.002208769753816597}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:22,226] Trial 9 finished with value: 0.004037028484549306 and parameters: {'max_depth': 2, 'n_estimators': 70, 'max_leaves': 5, 'learning_rate': 8.058056848127447e-05}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:22,795] Trial 10 finished with value: 0.026648355215486547 and parameters: {'max_depth': 8, 'n_estimators': 990, 'max_leaves': 10, 'learning_rate': 2.0468551772618326e-05}. Best is trial 1 with value: 0.8744435994835267.
# [I 2024-04-10 21:55:22,889] Trial 11 finished with value: 0.8769338732219712 and parameters: {'max_depth': 11, 'n_estimators': 690, 'max_leaves': 8, 'learning_rate': 0.03744597590131431}. Best is trial 11 with value: 0.8769338732219712.
# [I 2024-04-10 21:55:23,000] Trial 12 finished with value: 0.8792294117109852 and parameters: {'max_depth': 11, 'n_estimators': 650, 'max_leaves': 10, 'learning_rate': 0.021750371407334608}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,091] Trial 13 finished with value: 0.8749029251489936 and parameters: {'max_depth': 11, 'n_estimators': 610, 'max_leaves': 10, 'learning_rate': 0.020381626564218373}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,183] Trial 14 finished with value: 0.8762960534634511 and parameters: {'max_depth': 11, 'n_estimators': 650, 'max_leaves': 9, 'learning_rate': 0.022275267446259003}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,244] Trial 15 finished with value: 0.5023061211924441 and parameters: {'max_depth': 11, 'n_estimators': 510, 'max_leaves': 5, 'learning_rate': 0.0010816099502539208}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,310] Trial 16 finished with value: 0.8774249278648335 and parameters: {'max_depth': 8, 'n_estimators': 390, 'max_leaves': 11, 'learning_rate': 0.015648597565237753}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,374] Trial 17 finished with value: 0.878446514189903 and parameters: {'max_depth': 5, 'n_estimators': 370, 'max_leaves': 12, 'learning_rate': 0.01115739094663037}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,417] Trial 18 finished with value: 0.13397970970386408 and parameters: {'max_depth': 5, 'n_estimators': 170, 'max_leaves': 15, 'learning_rate': 0.0005556149659425846}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,462] Trial 19 finished with value: 0.8525753214520284 and parameters: {'max_depth': 5, 'n_estimators': 230, 'max_leaves': 11, 'learning_rate': 0.010490296677589096}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,535] Trial 20 finished with value: 0.47184549146471255 and parameters: {'max_depth': 8, 'n_estimators': 450, 'max_leaves': 9, 'learning_rate': 0.0010230726418008185}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,600] Trial 21 finished with value: 0.8744440105182503 and parameters: {'max_depth': 8, 'n_estimators': 390, 'max_leaves': 11, 'learning_rate': 0.010761184127501837}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,661] Trial 22 finished with value: 0.8715724718639676 and parameters: {'max_depth': 5, 'n_estimators': 350, 'max_leaves': 12, 'learning_rate': 0.0972556108030564}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,746] Trial 23 finished with value: 0.8784771395414029 and parameters: {'max_depth': 8, 'n_estimators': 550, 'max_leaves': 11, 'learning_rate': 0.021979808576964285}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,825] Trial 24 finished with value: 0.8755686417021223 and parameters: {'max_depth': 5, 'n_estimators': 530, 'max_leaves': 9, 'learning_rate': 0.037587430640284136}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,924] Trial 25 finished with value: 0.8747841183623845 and parameters: {'max_depth': 5, 'n_estimators': 590, 'max_leaves': 12, 'learning_rate': 0.005777205486837983}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:23,970] Trial 26 finished with value: 0.8790589347035332 and parameters: {'max_depth': 11, 'n_estimators': 190, 'max_leaves': 15, 'learning_rate': 0.04502339397499508}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:24,020] Trial 27 finished with value: 0.8777304128874027 and parameters: {'max_depth': 11, 'n_estimators': 170, 'max_leaves': 15, 'learning_rate': 0.06468062880882633}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:24,114] Trial 28 finished with value: 0.8748258687759166 and parameters: {'max_depth': 11, 'n_estimators': 930, 'max_leaves': 6, 'learning_rate': 0.026119589266913944}. Best is trial 12 with value: 0.8792294117109852.
# [I 2024-04-10 21:55:24,244] Trial 29 finished with value: 0.35748817648536635 and parameters: {'max_depth': 14, 'n_estimators': 690, 'max_leaves': 14, 'learning_rate': 0.0004323129323328382}. Best is trial 12 with value: 0.8792294117109852.
# {'max_depth': 11,
#  'n_estimators': 650,
#  'max_leaves': 10,
#  'learning_rate': 0.021750371407334608}

# %%
model_xgb_optuna = XGBRegressor(**study_xgb.best_params)
model_xgb_optuna.fit(X_train, y_train)
preds_xgb = model_xgb_optuna.predict(X_test)
r2_score(y_test, preds_xgb)
# Out:
# 0.9052864997894976

# %%
# Качество уменьшилось, оставим GBRegressor в качестве модели
